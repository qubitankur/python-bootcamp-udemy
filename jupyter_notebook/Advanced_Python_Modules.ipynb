# %% [markdown]
# # Collections Module

# %% [markdown]
# Counter

# %%
from collections import Counter

# %%
l = [1,1,1,1,12,12,1,2,22,22,2,22,2,2,2,4,4,4,3,3,3,3,555,5]
Counter(l)
# Out:
# Counter({1: 5, 12: 2, 2: 5, 22: 3, 4: 3, 3: 4, 555: 1, 5: 1})

# %%
s = 'asddddddddddfghjjjjjjjklllllll'
Counter(s)
# Out:
# Counter({'a': 1,
#          's': 1,
#          'd': 10,
#          'f': 1,
#          'g': 1,
#          'h': 1,
#          'j': 7,
#          'k': 1,
#          'l': 7})

# %%
s = 'How many times does each word show up in this sentence word word show up up?'

# %%
words = s.split()

Counter(words)
# Out:
# Counter({'How': 1,
#          'many': 1,
#          'times': 1,
#          'does': 1,
#          'each': 1,
#          'word': 3,
#          'show': 2,
#          'up': 2,
#          'in': 1,
#          'this': 1,
#          'sentence': 1,
#          'up?': 1})

# %%
c = Counter(words)

# %%
c.most_common(2)
# Out:
# [('word', 3), ('show', 2)]

# %% [raw]
# Commomn pattens when using the Counter() object
# sum(c.values())       total of all counts
# c.clear()             reset all counts
# list(c)               list unique elements
# set(c)                convert to a set
# dict(c)               convert to a regular dictionary
# c.items()             convert to a list of (elem,cnt) pairs
# Counter(dict(list_of_pairs))       convert from a list of(elem, cnt) pairs
# c.most_common()[:-n-1:-1]          n least common elements
# c += Counter()                     remove zero and negative counts

# %%
sum(c.values())
# Out:
# 16

# %%
Counter(dict(c))
# Out:
# Counter({'How': 1,
#          'many': 1,
#          'times': 1,
#          'does': 1,
#          'each': 1,
#          'word': 3,
#          'show': 2,
#          'up': 2,
#          'in': 1,
#          'this': 1,
#          'sentence': 1,
#          'up?': 1})

# %% [markdown]
# defaultdict

# %%
from collections import defaultdict

# %%
d = {'k1':1}

# %%
d['k1']
# Out:
# 1

# %%
d['d2']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-0a6e17ccab26> in <module>
# ----> 1 d['d2']
#
# KeyError: 'd2'

# %%
d = defaultdict(object)

# %%
d['one']

# %%
for item in d:
    print(item)
# Out:
# one

# %%
d = defaultdict(lambda: 0)

# %%
d['one']
# Out:
# 0

# %%
d['two'] = 2

# %%
d
# Out:
# defaultdict(<function __main__.<lambda>()>, {'one': 0, 'two': 2})

# %% [markdown]
# OrderedDict

# %%
d = {}

d['a'] = 1
d['b'] = 2
d['c'] = 6
d['d'] = 4
d['e'] = 5
d['f'] = 3

# %%
d
# Out:
# {'a': 1, 'b': 2, 'c': 6, 'd': 4, 'e': 5, 'f': 3}

# %%
for k,v in d.items():
    print (k,v)
# Out:
# a 1
# b 2
# c 6
# d 4
# e 5
# f 3

# %%
from collections import OrderedDict

# %%
d = OrderedDict()

# %%
d['a'] = 1
d['b'] = 2
d['c'] = 6
d['d'] = 4
d['e'] = 5
d['f'] = 3

# %%
for k,v in d.items():
    print (k,v)
# Out:
# a 1
# b 2
# c 6
# d 4
# e 5
# f 3

# %% [raw]
# namedtuple

# %%
t = (1,2,3)

# %%
t[0]
# Out:
# 1

# %%
from collections import namedtuple

# %%
Dog = namedtuple('Dog','age bread name')

# %%
sam = Dog(age = 2, bread = 'lab', name = 'Sammy')

# %%
sam.age
# Out:
# 2

# %%
sam
# Out:
# Dog(age=2, bread='lab', name='Sammy')

# %%
Cat = namedtuple('Cat','fur claws name')

# %%
c = Cat(fur='Fuzzy',claws=False,name ='Kitty')

# %% [markdown]
# Datetime

# %%
import datetime

# %%
t = datetime.time(5,25,1)

# %%
print (t)
# Out:
# 05:25:01

# %%
t.microsecond
# Out:
# 0

# %%
t.hour
# Out:
# 5

# %%
print (datetime.time.min)
# Out:
# 00:00:00

# %%
print (datetime.time.max)
# Out:
# 23:59:59.999999

# %%
print(datetime.time.resolution)
# Out:
# 0:00:00.000001

# %%
today =datetime.date.today()

# %%
print(today)
# Out:
# 2019-12-29

# %%
today.timetuple()
# Out:
# time.struct_time(tm_year=2019, tm_mon=12, tm_mday=29, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=363, tm_isdst=-1)

# %%
today.month
# Out:
# 12

# %% [markdown]
# Python Debugger

# %%
import pdb

# %%
x = [1,2,3,4]
y = 2
z = 3

result = y + z
print(result)

pdb.set_trace()
result2 = y + x
print(result2)
# Out:
# 5
# --Return--
# > <ipython-input-49-797a5ab3f2a4>(8)<module>()->None
# -> pdb.set_trace()
# (Pdb) y+z
# 5
# (Pdb) q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-49-797a5ab3f2a4> in <module>
#       6 print(result)
#       7
# ----> 8 pdb.set_trace()
#       9
#      10 result2 = y + x
#
# ~/anaconda3/lib/python3.7/bdb.py in trace_dispatch(self, frame, event, arg)
#      90             return self.dispatch_call(frame, arg)
#      91         if event == 'return':
# ---> 92             return self.dispatch_return(frame, arg)
#      93         if event == 'exception':
#      94             return self.dispatch_exception(frame, arg)
#
# ~/anaconda3/lib/python3.7/bdb.py in dispatch_return(self, frame, arg)
#     152             finally:
#     153                 self.frame_returning = None
# --> 154             if self.quitting: raise BdbQuit
# ...

# %% [markdown]
# Timing your code- timeit

# %%
import timeit

# %%
'0-1-2-3-.....-99'
# Out:
# '0-1-2-3-.....-99'

# %%
(timeit.timeit('"-".join(str(n) for n in range(100)) ',number=1000))
# Out:
# 0.126700492000964

# %%
(timeit.timeit('"-".join([str(n) for n in range(100)]) ',number=1000))    #list_comprehension
# Out:
# 0.06774017499992624

# %%
timeit.timeit('"-".join(map(str, range(100)))', number=10000)
# Out:
# 0.4819821899982344

# %%
# %timeit "-".join(str(n) for n in range(100))
# Out:
# 93.9 µs ± 328 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %timeit "-".join([str(n) for n in range(100)])
# Out:
# 65.9 µs ± 336 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# Regular Expression

# %%
import re

# %%
patterns = ['term1','term2']

# %%
text = 'This is a string with term1, but not the other term '

# %%
re.search('hello','hello world!')
# Out:
# <re.Match object; span=(0, 5), match='hello'>

# %%
for pattern in patterns:
    print ('Seaching for "%s" in: \n"%s"' % (pattern, text))
    
    #Check for match
    if re.search(pattern, text):
        print('\n')
        print('Match was found. \n')
    else:
        print('\n')
        print('No match was found. \n')
# Out:
# Seaching for "term1" in:
# "This is a string with term1, but not the other term "
#
#
# Match was found.
#
# Seaching for "term2" in:
# "This is a string with term1, but not the other term "
#
#
# No match was found.

# %%
match = re.search(patterns[0],text)

# %%
type(match)
# Out:
# re.Match

# %%
match.start()
# Out:
# 22

# %%
match.end()
# Out:
# 27

# %%
match.regs
# Out:
# ((22, 27),)

# %%
split_term ='@'

phrase = 'What is your email, it is hello@gmail.com?'

# %%
re.split(split_term,phrase)
# Out:
# ['What is your email, it is hello', 'gmail.com?']

# %%
'hello world'.split()
# Out:
# ['hello', 'world']

# %%
re.findall('match', 'Here is one match, here is another match')
# Out:
# ['match', 'match']

# %%
def multi_re_find(patterns,phrase):
    '''
    Takes in a list of regex patterns
    prints a list of all matches
    '''
    for pattern in patterns:
        print('Searching the phrase using the re-check: %r' %pattern)
        print(re.findall(pattern,phrase))
        print('\n')

# %%
test_phrase = 'sdsd..sssddd...sdddsddd...dsds...dsssss...sddd'
test_patterns = [ 'sd*',                # s followed by zero or more d's
                'sd+',                   # s followed by one or more d's
                'sd?' ,                  # s followed by zero or one d's
                'sd{3}',                 # s followed by three d's
                'sd{2,3}',              # s followed by two to three d's
                ]

multi_re_find(test_patterns,test_phrase)
# Out:
# Searching the phrase using the re-check: 'sd*'
# ['sd', 'sd', 's', 's', 'sddd', 'sddd', 'sddd', 'sd', 's', 's', 's', 's', 's', 's', 'sddd']
#
#
# Searching the phrase using the re-check: 'sd+'
# ['sd', 'sd', 'sddd', 'sddd', 'sddd', 'sd', 'sddd']
#
#
# Searching the phrase using the re-check: 'sd?'
# ['sd', 'sd', 's', 's', 'sd', 'sd', 'sd', 'sd', 's', 's', 's', 's', 's', 's', 'sd']
#
#
# Searching the phrase using the re-check: 'sd{3}'
# ['sddd', 'sddd', 'sddd', 'sddd']
#
#
# Searching the phrase using the re-check: 'sd{2,3}'
# ['sddd', 'sddd', 'sddd', 'sddd']

# %% [markdown]
# StringIO
# The stringIO module implements an in-memory file like object. This object can then be used as input or output to most functions that would expect a standard file object.

# %%
from io import StringIO
import io

# %%
message = 'This is just a normal string.'

# %% [raw]
# Advanced Numbers

# %%
hex(12)
# Out:
# '0xc'

# %%
bin(123)
# Out:
# '0b1111011'

# %%
 pow(2,3)
# Out:
# 8

# %%
abs(-3)
# Out:
# 3

# %%
round(3.6)
# Out:
# 4

# %% [markdown]
# Advanced Strings

# %%
s = 'Hello world'

# %%
s.capitalize()
# Out:
# 'Hello world'

# %%
s.upper()
# Out:
# 'HELLO WORLD'

# %%
s.lower()
# Out:
# 'hello world'

# %%
s.center(20,'z')
# Out:
# 'zzzzHello worldzzzzz'

# %%
s.isalnum()
# Out:
# False

# %%
s.isalpha()
# Out:
# False

# %%
s.istitle()
# Out:
# False

# %%
s = 'hihihihihihihiiiihh'

# %%
s.partition('i')
# Out:
# ('h', 'i', 'hihihihihihiiiihh')

# %% [markdown]
# Advanced Sets

# %%
s = set()

# %%
s.add(2)

# %%
s.add(1)

# %%
s
# Out:
# {1, 2}

# %%
sc = s.copy()

# %%
s.add(4)

# %%
sc
# Out:
# {1, 2}

# %%
s
# Out:
# {1, 2, 4}

# %%
s.difference(sc)
# Out:
# {4}

# %%
s1 = {1,2,3}

# %%
s2 = {1,5,6}

# %%
s1.difference_update(s2)

# %%
s1
# Out:
# {2, 3}

# %%
s.discard(2)

# %%
s
# Out:
# {1, 4}

# %%
s1.intersection(s2)
# Out:
# set()

# %%
s1 = {1,2,3,4}
s2 = {1,2,3}
s3 = {5}

# %%
s1.isdisjoint(s2)
# Out:
# False

# %%
s2.issubset(s1)
# Out:
# True

# %%
s1.issuperset(s2)
# Out:
# True

# %%
s1.symmetric_difference(s2)
# Out:
# {4}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# Advanced Dictionaries

# %%
d = {'k1':1, 'k2':2}

# %%
{k:v**2 for k,v in zip (['a','b'],range(2))}
# Out:
# {'a': 0, 'b': 1}

# %%
{v:v**2 for v in range(10)}
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %%
for k in d.keys():
    print(k)
# Out:
# k1
# k2

# %%
d.values()
# Out:
# dict_values([1, 2])

# %% [markdown]
# Advanced Lists

# %%
l = [1,2,3]

# %%
l.append
(4)
# Out:
# 4

# %%
l.count(1)
# Out:
# 1

# %%
x = [1,2,3,4,6,7]
x.extend([12,52])
print(x)
# Out:
# [1, 2, 3, 4, 6, 7, 12, 52]

# %%
l
# Out:
# [1, 2, 3]

# %%
l.insert(2,'inserted')

# %%
l
# Out:
# [1, 2, 'inserted', 3]

# %%
l.pop(0)
# Out:
# 1

# %%
l.reverse()

# %%
l
# Out:
# [3, 'inserted', 2]
